# %% [markdown]
# # DISCRETE MATH II LECTURE 2 ANSWERS
# **Student Name**: Franchesca Marianne Kho
# **Subject**: Discrete Math
# **Teacher**: Gerard Ompad
# **Schedule**: Tuesday & Thursday, 12:00 - 1:30 PM

# %% [markdown]
# $\textbf{Programming Assignments}$
# -
#
# Intructions:
# - Use Latex to write your solution.
# - Push your solution to your github repository.

# %% [markdown]
# Task 1:
# Consider the following experiment:
#
# 1. The experiment consists of $n$ identical trials.
# 2. The outcome of each trial falls into one of $k$ classes or cells.
# 3. The probability that the outcome of a single trial falls into cell $i$, is $p_i,i = 1,2,...,k$ and remains the same from trial to trial. Notice that $p_1+p_2+p_3+···+p_k =1.$
# 4. The trials are independent.
# 5. The random variables of interest are $Y_1 , Y_2 , . . . , Y_k$, where $Y_i$ equals the number of trials for which the outcome falls into cell $i$. Notice that $Y_1 +Y_2 +Y_3 +···+Y_k =n$.
# 6. The joint probability distribution $P(y) = \frac{n!}{y_1!y_2!y_3!...y_n!} P_1^{y_1} P_2^{y_2} P_3^{y_3}....P_n^{y_n}$
#
# Question 1: Show that the expected value $E[y] = \Sigma y \cdotp P(y) = n \cdot p_i$

# %% [markdown]
# #### Answer to Question 1:

# %% [markdown]
# <b> Show that the expected value:
# </b> $E[y] = \Sigma y \cdotp P(y) = n \cdot p_i$
#
#    To show that the expected value $ E[Y_i] = n \cdot p_i $, we can follow these steps:
#
# <b> Step 1: Defining the expected value:</b>
#    The expected value of $ Y_i $ is given by:
#    $
#    E[Y_i] = \sum_{y_i} y_i \cdot P(Y_i = y_i)
#    $
#
# <b> Step 2: Use the Joint Distribution: </b>
#    The joint probability distribution of $ Y_1, Y_2, \ldots, Y_k $ is:
#    $
#    P(y_1, y_2, \ldots, y_k) = \frac{n!}{y_1! y_2! \cdots y_k!} p_1^{y_1} p_2^{y_2} \cdots p_k^{y_k}
#    $
#    where $ y_1 + y_2 + \cdots + y_k = n $.
#
# <b> Step 3: Marginal Distribution of $ Y_i $: </b>
#    Since the trials are independent and follow the multinomial distribution, the marginal distribution of $ Y_i $ is binomial:
#    $
#    Y_i \sim \text{Binomial}(n, p_i)
#    $
#    The binomial probability mass function is:
#    $
#    P(Y_i = y_i) = \binom{n}{y_i} p_i^{y_i} (1 - p_i)^{n - y_i}
#    $
#
# <b> Step 4:. Expected Value of Binomial Random Variable: </b>
#    For a binomial random variable $ Y_i $ with parameters $ n $ and $ p_i $, the expected value is well known:
#    $
#    E[Y_i] = n \cdot p_i
#    $
#
# <b> Thus, we have: </b>
#    $
#    E[Y_i] = n \cdot p_i
#    $
#
#    For completeness, let’s derive this using the definition of expected value explicitly.
#
# <b> Step 5: Derivation Using Definition: </b>
#    $
#    E[Y_i] = \sum_{y_i=0}^{n} y_i \cdot P(Y_i = y_i)
#    $
#
#    Substitute the binomial probability mass function:
#    $
#    E[Y_i] = \sum_{y_i=0}^{n} y_i \cdot \binom{n}{y_i} p_i^{y_i} (1 - p_i)^{n - y_i}
#    $
#
# <b> Step 6: Simplify the Summation: </b>
#    $
#    E[Y_i] = \sum_{y_i=0}^{n} y_i \cdot \frac{n!}{y_i!(n - y_i)!} p_i^{y_i} (1 - p_i)^{n - y_i}
#    $
#
#    Notice that $ y_i \cdot \frac{n!}{y_i!(n - y_i)!} = n \cdot \frac{(n-1)!}{(y_i - 1)! (n - y_i)!} = n \cdot \binom{n-1}{y_i-1} $, so we get:
#    $
#    E[Y_i] = n \cdot \sum_{y_i=0}^{n} \binom{n-1}{y_i-1} p_i^{y_i} (1 - p_i)^{n - y_i}
#    $
#
# <b> Step 7: Adjust the Summation Index: </b>
#    Let $ j = y_i - 1 $. Then the summation becomes:
#    $
#    E[Y_i] = n \cdot \sum_{j=-1}^{n-1} \binom{n-1}{j} p_i^{j+1} (1 - p_i)^{n-1-j}
#    $
#
#    Notice that when $ j = -1 $, the term is zero because the binomial coefficient $ \binom{n-1}{-1} = 0 $.
#
#    Therefore, we can write:
#    $
#    E[Y_i] = n \cdot p_i \sum_{j=0}^{n-1} \binom{n-1}{j} p_i^{j} (1 - p_i)^{n-1-j}
#    $
#
# <b> Step 8: Recognize the Binomial Theorem: </b>
#    The summation is a binomial expansion:
#    $
#    \sum_{j=0}^{n-1} \binom{n-1}{j} p_i^j (1 - p_i)^{n-1-j} = (p_i + (1 - p_i))^{n-1} = 1
#    $
#
# <b> Therefore: </b>
#    $
#    E[Y_i] = n \cdot p_i \cdot 1 = n \cdot p_i
#    $
#
# <b> Thus, </b>
#    the expected value $ E[Y_i] $ is indeed $ n \cdot p_i $.
#
#    $
#    {E[Y_i] = n \cdot p_i}
#    $

# %% [markdown]
# <br>

# %% [markdown]
# Question 2: Given the following data
# \begin{gather}
# \begin{bmatrix}
# \begin{array}{c|c}
# Age & Proportion \\
# 18-24 & 0.18 \\
# 25-34 & 0.23 \\
# 35-44 & 0.16 \\
# 45-64 & 0.27 \\
# 65-100 & 0.16 \\
# \end{array}
# \end{bmatrix}
# \end{gather}
#
# If 500 adults are sampled  randomly, find the probability rhat the sample contains 100 person between 18 and 24, 200 between, 200 between the ages of 25 and 34, and 200 between the ages of 45 and 64.. What is the expected value for to obtain a person in the 65 and above?

# %% [markdown]
# #### Answer to Question 2:

# %% [markdown]
# **Multinomial Probability**
#
# The probability mass function for the multinomial distribution is given by:
# $
# P(Y_1 = y_1, Y_2 = y_2, \ldots, Y_k = y_k) = \frac{n!}{y_1! y_2! \cdots y_k!} p_1^{y_1} p_2^{y_2} \cdots p_k^{y_k}
# $
# where $ n = 500 $ and $ p_i $ are the proportions for each age group.
#
# We need to find:
# $
# P(Y_{18-24} = 100, Y_{25-34} = 200, Y_{45-64} = 200)
# $
#
# First, we need to verify if the remaining counts for other age groups make sense:
#
# - People aged 35-44: Since we don't have any condition on this group, we let it be $ y_{35-44} $.
# - People aged 65-100: Since we don't have any condition on this group, we let it be $ y_{65-100} $.
#
#
# From the total sample size, we have:
# $
# Y_{35-44} + Y_{65-100} = 500 - (100 + 200 + 200) = 500 - 500 = 0
# $
#
# This implies $ Y_{35-44} = 0 $ and $ Y_{65-100} = 0 $.
#
# **Substituting into the Multinomial PMF:**
#
# Given:
# $
# n = 500, \quad y_1 = 100, \quad y_2 = 200, \quad y_3 = 0, \quad y_4 = 200, \quad y_5 = 0
# $
# $
# p_1 = 0.18, \quad p_2 = 0.23, \quad p_3 = 0.16, \quad p_4 = 0.27, \quad p_5 = 0.16
# $
#
# The probability is:
# $
# P(Y_1 = 100, Y_2 = 200, Y_4 = 200) = \frac{500!}{100! \cdot 200! \cdot 0! \cdot 200! \cdot 0!} \cdot 0.18^{100} \cdot 0.23^{200} \cdot 0.16^0 \cdot 0.27^{200} \cdot 0.16^0
# $

# %% [markdown]
# The expected value $ E[Y_i] $ for a multinomial random variable $ Y_i $ with sample size $ n $ and probability $ p_i $ is given by:
# $
# E[Y_i] = n \cdot p_i
# $
#
# For the age group 65-100:
# $
# n = 500, \quad p_i = 0.16
# $
#
# Thus:
# $
# E[Y_{65-100}] = 500 \cdot 0.16 = 80
# $
#
#
# - The probability of getting 100 people aged 18-24, 200 people aged 25-34, and 200 people aged 45-64 in a sample of 500 is given by:
#     $
#     P(Y_1 = 100, Y_2 = 200, Y_4 = 200) = \frac{500!}{100! \cdot 200! \cdot 200!} \cdot 0.18^{100} \cdot 0.23^{200} \cdot 0.27^{200}
#     $
# - The expected value for obtaining a person in the age group 65-100 is:
#     $
#     E[Y_{65-100}] = 80
#     $

# %% [markdown]
# <br>

# %% [markdown]
# Task 2: Consider the following experiment:
#
# 1. The experiment consists of a fixed number, $n$, of identical trials.
# 2. Each trial results in one of two outcomes: success, $S$, or failure, $F$.
# 3. The probability of success on a single trial is equal to some value $p$ and remains the same from trial to trial. The probability of a failure is equal to q = $(1 − p)$.
# 4. The trials are independent.
# 5. The random variable of interest is $Y$ , the number of successes observed during the $n$ trials.
#
# Question 1: From the following steps shown above, derive the probability distribution of the experiment.
#
# Question 2: Show that the expectation of this probability distribution is $E[y] = \Sigma y \cdotp P(y) = np$.
#
# Question 3: Experience has shown that 30% of all persons afflicted by a certain illness recover. A drug company has developed a new medication. Ten people with the illness were selected at random and received the medication; nine recovered shortly thereafter. Suppose that the medication was absolutely worthless. What is the probability that at least nine of ten receiving the medication will recover?
#
# Question 4: Suppose that a lot of 5000 electrical fuses contains 5% defectives. If a sample of 5 fuses is tested, find the probability of observing at least one defective.

# %% [markdown]
# ##### Question 1 Answer:

# %% [markdown]
# We aim to derive the probability distribution of the random variable $Y$.
#
# The random variable $Y$ follows a binomial distribution because:
#
# - There are a fixed number of trials, $n$.
# - Each trial has two possible outcomes.
# - The probability of success $p$ is constant for each trial.
# - The trials are independent.
#
# The probability mass function (PMF) of a binomially distributed random variable $Y$ is given by:
#
# $
# P(Y = k) = \binom{n}{k} p^k (1-p)^{n-k}
# $
#
# for $k = 0, 1, 2, \ldots, n$.
#
# Here, $\binom{n}{k}$ is the binomial coefficient and is calculated as:
#
# $
# \binom{n}{k} = \frac{n!}{k!(n-k)!}
# $
#
# Therefore, the probability distribution of $Y$ is:
#
# $
# P(Y = k) = \frac{n!}{k!(n-k)!} p^k (1-p)^{n-k}
# $
#
# for $k = 0, 1, 2, \ldots, n$.

# %% [markdown]
# <b> Question 2 Answer </b>

# %% [markdown]
# To show that the expectation $E[Y]$ of a binomial random variable $Y$ with parameters $n$ and $p$ is equal to $np$, we start with the definition of the expectation:
#
# $
# E[Y] = \sum_{k=0}^{n} k \cdot P(Y = k)
# $
#
# Given that $Y$ follows a binomial distribution, the probability mass function is:
#
# $
# P(Y = k) = \binom{n}{k} p^k (1-p)^{n-k}
# $
#
# ### Thus,
# the expectation can be written as:
#
# $
# E[Y] = \sum_{k=0}^{n} k \cdot \binom{n}{k} p^k (1-p)^{n-k}
# $
#
# To simplify this, we recognize that:
#
# $
# \binom{n}{k} = \frac{n!}{k!(n-k)!}
# $
#
# Rewriting the expectation:
#
# $
# E[Y] = \sum_{k=0}^{n} k \cdot \frac{n!}{k!(n-k)!} p^k (1-p)^{n-k}
# $
#
# We can factor out an $n$ from the binomial coefficient:
#
# $
# E[Y] = \sum_{k=0}^{n} k \cdot \frac{n}{k} \cdot \frac{(n-1)!}{(k-1)!(n-k)!} p^k (1-p)^{n-k}
# $
#
# Simplifying the terms:
#
# $
# E[Y] = n \sum_{k=1}^{n} \frac{(n-1)!}{(k-1)!(n-k)!} p^k (1-p)^{n-k}
# $
#
# Next, we make a change of index in the summation. Let $j = k-1$. Then when $k$ ranges from $1$ to $n$, $j$ ranges from $0$ to $n-1$. Substituting $k = j+1$:
#
# $
# E[Y] = n \sum_{j=0}^{n-1} \frac{(n-1)!}{j!(n-1-j)!} p^{j+1} (1-p)^{n-1-j}
# $
#
# This can be written as:
#
# $
# E[Y] = n p \sum_{j=0}^{n-1} \frac{(n-1)!}{j!(n-1-j)!} p^j (1-p)^{n-1-j}
# $
#
# Recognize that the summation is now the binomial expansion of $(p + (1-p))^{n-1}$, which equals $1$:
#
# $
# \sum_{j=0}^{n-1} \binom{n-1}{j} p^j (1-p)^{n-1-j} = 1
# $
#
# ### Thus,
#
# $
# E[Y] = n p \cdot 1 = np
# $
#
# Therefore, the expectation of the binomial random variable $Y$ is:
#
# $
# E[Y] = np
# $

# %% [markdown]
# ##### Question 3 Answer:

# %% [markdown]
# <b> Given: </b>
# - The probability of recovery without the medication, $p = 0.30$.
# - The number of trials, $n = 10$.
# - We want to find the probability that at least nine people recover out of the ten.
#
# The random variable $Y$ follows a binomial distribution with parameters $n$ and $p$:
#
# $
# Y \sim \text{Binomial}(n=10, p=0.30)
# $
#
# We need to find:
#
# $
# P(Y \geq 9) = P(Y = 9) + P(Y = 10)
# $
#
# The probability mass function (PMF) of a binomial distribution is:
#
# $
# P(Y = k) = \binom{n}{k} p^k (1-p)^{n-k}
# $
#
# First, calculate $P(Y = 9)$:
#
# $
# P(Y = 9) = \binom{10}{9} (0.30)^9 (0.70)^1
# $
#
# $
# \binom{10}{9} = \frac{10!}{9!1!} = 10
# $
#
# $
# P(Y = 9) = 10 \times (0.30)^9 \times (0.70)^1
# $
#
# $
# P(Y = 9) = 10 \times (0.30)^9 \times 0.70
# $
#
# Next, calculate $P(Y = 10)$:
#
# $
# P(Y = 10) = \binom{10}{10} (0.30)^{10} (0.70)^0
# $
#
# $
# \binom{10}{10} = 1
# $
#
# $
# P(Y = 10) = 1 \times (0.30)^{10} \times 1
# $
#
# $
# P(Y = 10) = (0.30)^{10}
# $
#
# Now, sum these probabilities:
#
# $
# P(Y \geq 9) = P(Y = 9) + P(Y = 10)
# $
#
# $
# P(Y \geq 9) = 10 \times (0.30)^9 \times 0.70 + (0.30)^{10}
# $
#
# Calculate the numerical values:
#
# $
# P(Y = 9) \approx 10 \times (1.9683 \times 10^{-5}) \times 0.70 \approx 10 \times 1.37781 \times 10^{-5} \approx 1.37781 \times 10^{-4}
# $
#
# $
# P(Y = 10) \approx (0.30)^{10} \approx 5.9049 \times 10^{-6}
# $
#
# $
# P(Y \geq 9) \approx 1.37781 \times 10^{-4} + 5.9049 \times 10^{-6} \approx 1.43686 \times 10^{-4}
# $
#
# <b> Thus, </b>
# the probability that at least nine out of ten people will recover, assuming the medication is worthless, is approximately:
#
# $
# P(Y \geq 9) \approx 1.43686 \times 10^{-4}
# $

# %% [markdown]
# ##### Question 4 Answer:

# %% [markdown]
# Given:
# - The lot contains 5000 electrical fuses.
# - 5% of the fuses are defective, implying $p = 0.05$.
# - We want to find the probability of observing at least one defective fuse in a sample of 5.
#
# The random variable $Y$ follows a binomial distribution with parameters $n$ and $p$:
#
# $
# Y \sim \text{Binomial}(n=5, p=0.05)
# $
#
# We need to find:
#
# $
# P(Y \geq 1) = 1 - P(Y = 0)
# $
#
# The probability mass function (PMF) of a binomial distribution is:
#
# $
# P(Y = k) = \binom{n}{k} p^k (1-p)^{n-k}
# $
#
# First, calculate $P(Y = 0)$:
#
# $
# P(Y = 0) = \binom{5}{0} (0.05)^0 (0.95)^5
# $
#
# $
# \binom{5}{0} = 1
# $
#
# $
# P(Y = 0) = 1 \times 1 \times (0.95)^5
# $
#
# Now, calculate $1 - P(Y = 0)$:
#
# $
# P(Y \geq 1) = 1 - (0.95)^5
# $
#
# $
# P(Y \geq 1) = 1 - 0.77378
# $
#
# $
# P(Y \geq 1) \approx 0.22622
# $
#
# <b> Thus, </b>
# the probability of observing at least one defective fuse in a sample of 5 is approximately:
#
# $
# P(Y \geq 1) \approx 0.22622
# $

# %% [markdown]
# <br>

# %% [markdown]
# Task 3: Consider a probility distribution of $p(y) = \frac{\lambda^y}{y!} e^{-\lambda}$.
#
# Question 1: Find a general formula for the expected value of this distribution.

# %% [markdown]
# ##### Question 1 Answer:

# %% [markdown]
# Find a general formula for the expected value of this distribution.
#
# \begin{aligned}
# E[Y] &= \sum_{y=0}^{\infty} y \cdot \frac{\lambda^y}{y!} e^{-\lambda} \\
# &= \sum_{y=1}^{\infty} y \cdot \frac{\lambda^y}{y!} e^{-\lambda} \quad \text{(since } y = 0 \text{ term is 0)} \\
# &= \sum_{y=1}^{\infty} \frac{\lambda^y}{(y-1)!} e^{-\lambda} \\
# &= e^{-\lambda} \sum_{y=1}^{\infty} \frac{\lambda^y}{(y-1)!} \quad \text{(pulling out } e^{-\lambda} \text{ as a constant)} \\
# &= e^{-\lambda} \sum_{y=0}^{\infty} \frac{\lambda^{y+1}}{y!} \quad \text{(reindexing the sum)} \\
# &= e^{-\lambda} \cdot \lambda \sum_{y=0}^{\infty} \frac{\lambda^y}{y!} \quad \text{(factor out } \lambda \text{ from the sum)} \\
# &= e^{-\lambda} \cdot \lambda \cdot e^{\lambda} \quad \text{(using the Taylor series expansion of } e^x) \\
# &= \lambda \quad \text{(simplify)}
# \end{aligned}

# %% [markdown]
# ##### Question 2 Answer:

# %% [markdown]
# The probability of a region not containing any seedlings is the complement of the probability of it containing at least one seedling. Let $p$ be the probability that a region contains at least one seedling. Then, the probability that none of the regions contain seedlings is $1 - p$.
#
# Given that the mean density of seedlings is approximately five per square yard, the probability of a square yard containing no seedlings is $e^{-5}$ (since this follows a Poisson distribution with mean $\lambda = 5$).
#
# Therefore, the probability that a region of one square yard contains at least one seedling is $1 - e^{-5}$.
#
# Since the sampling regions are independent, the probability that none of the ten regions contain seedlings is $(1 - e^{-5})^{10}$.
#
# Thus, the probability that none of the regions will contain seedlings is:
#
# $ 1 - (1 - e^{-5})^{10} $
#
# This expression evaluates to approximately 0.00674.
